# %% [markdown]
# # Import Library

# %%
from utils import preprocessor
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from utils import loss
from core import MusicRecognition
from utils import saver
from core import KNN

# %% [markdown]
# # Load Dataset

# %%
#load dataset
data = pd.read_csv('dataset/Emotion_features_Basshouse.csv')
data2 = pd.read_csv('dataset/Emotion_features_deephouse.csv')
data = data.append(data2, ignore_index=True)
data
# Out:
#      Unnamed: 0                                         song_name       Genre  \
# 0             1  01 Castion & Dylerz feat. NEAD - Take Me (Ex.mp3  Bass House
# 1             2  010. DJ Snake feat. Lauv - A Different Way (.mp3  Bass House
# 2             3                 03 Down On Love (Moksi Remix).mp3  Bass House
# 3             4                                    04 Kill It.mp3  Bass House
# 4             5  04. Tujamo - One On One (Vion Konger Remix) .mp3  Bass House
# ..          ...                                               ...         ...
# 153          44  Tones and I - Dance Monkey (Robin Tayger Ext.wav  Deep House
# 154          45  Zedd & Jasmine Thompson - Funny (Breathe Car.mp3  Deep House
# 155          46       Guy Burns - Lie Machine [www.slider.kz].mp3  Deep House
# 156          47  Low Steppa - Heard It All Before (Low Steppa.mp3  Deep House
# 157          48  Mike Newman - Boom Boom (Scott Diaz Remix) [.mp3  Deep House
#
#      Class  Energy       tempo  total_beats  average_beats  chroma_stft_mean  \
# 0    Relax       6  129.199219       152815    1242.398374          0.557802
# 1    Angry       5  129.199219       153760    1260.327869          0.453072
# 2    Happy       6  129.199219       164504    1265.415385          0.438003
# 3    Angry       3  129.199219       154417    1245.298387          0.502991
# 4    Happy       8  129.199219       154481    1245.814516          0.508615
# ..     ...     ...         ...          ...            ...               ...
# 153  Happy       5  123.046875       133316    1179.787611          0.539563
# 154  Happy       4  112.347147       140841    1268.837838          0.324272
# 155  Relax       3  129.199219       155565    1254.556452          0.637487
# 156  Relax       4  123.046875       155794    1309.193277          0.612734
# 157  Relax       4  123.046875       157935    1294.549180          0.525999
#
#      chroma_stft_std  ...   zcr_var     harm_mean  harm_std  harm_var  \
# 0           0.262862  ...  0.014946  1.000000e-05  0.159635  0.025483
# 1           0.306240  ...  0.012775 -2.480000e-05  0.237943  0.056617
# 2           0.316769  ...  0.014490 -6.520000e-06  0.134911  0.018201
# 3           0.302825  ...  0.008881  2.700000e-05  0.283810  0.080548
# 4           0.287085  ...  0.005656  5.580000e-06  0.258874  0.067016
# ..               ...  ...       ...           ...       ...       ...
# 153         0.276192  ...  0.028785 -2.490000e-06  0.211524  0.044742
# 154         0.292907  ...  0.003293 -3.970000e-07  0.198123  0.039253
# 155         0.229090  ...  0.029205  7.970000e-07  0.044332  0.001965
# 156         0.252979  ...  0.027857 -2.560000e-05  0.166363  0.027677
# 157         0.282076  ...  0.028875  4.700000e-06  0.093228  0.008692
#
#      perc_mean  perc_std  perc_var  frame_mean  frame_std  frame_var
# 0     0.000208  0.108167  0.011700    2.275556   1.346017   1.811760
# 1     0.000008  0.174161  0.030332    2.362630   1.175441   1.381661
# 2    -0.000429  0.204549  0.041840    1.790259   1.084248   1.175593
# 3     0.000402  0.193737  0.037534    1.789098   0.979939   0.960281
# 4    -0.000730  0.123336  0.015212    3.868444   2.171114   4.713737
# ..         ...       ...       ...         ...        ...        ...
# 153   0.000087  0.191713  0.036754    2.569288   1.394634   1.945003
# 154   0.000003  0.091915  0.008448    4.376961   2.358072   5.560503
# 155   0.000118  0.216673  0.046947    1.993433   1.109716   1.231471
# 156   0.000024  0.234461  0.054972    3.787175   1.659486   2.753894
# 157  -0.000115  0.218301  0.047655    2.346376   1.389991   1.932074
#
# [158 rows x 59 columns]

# %% [markdown]
# # Feature Engineering to NP Array

# %%
#preprocess dataset
dataset_x, dataset_y = preprocessor.feature_engineering_knn_aidj(data)

# %% [markdown]
# # Split between train and test

# %%
#dataset splitting
x_train, x_test, y_train, y_test = train_test_split(dataset_x, dataset_y, test_size=0.1)
x_train
# Out:
# array([[1.23046875e+02, 1.44187000e+05, 1.21165546e+03, ...,
#         1.77632653e+00, 9.87803726e-01, 9.75756200e-01],
#        [1.29199219e+02, 1.65202000e+05, 1.40001695e+03, ...,
#         9.67227211e+00, 3.67559835e+00, 1.35100233e+01],
#        [1.29199219e+02, 1.32445000e+05, 1.16179825e+03, ...,
#         2.76549660e+00, 1.42771380e+00, 2.03836670e+00],
#        ...,
#        [1.29199219e+02, 1.64341000e+05, 1.28391406e+03, ...,
#         1.93073923e+00, 9.11017839e-01, 8.29953503e-01],
#        [1.29199219e+02, 1.61889000e+05, 1.27471654e+03, ...,
#         2.08747392e+00, 1.17084535e+00, 1.37087883e+00],
#        [1.29199219e+02, 1.21411000e+05, 1.10373636e+03, ...,
#         2.29064853e+00, 1.35133902e+00, 1.82611715e+00]])

# %% [markdown]
# # Reduce dimension using PCA
# ## Notes that the explained variance > 99% to make sure data persistence

# %%
#dimension reduction
from sklearn.decomposition import PCA
import numpy as np
pca = PCA(n_components=2)
pca.fit(x_train) #PCA based on dataset training only
pca.explained_variance_ratio_.sum()
# Out:
# 0.9982183591443247

# %%
x_train_rd = pca.transform(x_train)
print(x_train_rd.shape)
# Out:
# (142, 2)

# %%
for neigh in range(20):
    knn = KNN.KNN(num_neighbor = neigh+1)
    # print(x_train)
    knn.train(x_train_rd, y_train)

    #yield acc
    y_pred = knn.infer(pca.transform(x_test))
    # print(y_pred.T[0])
    # print(loss.hamming_score(y_test, y_pred))
    print(accuracy_score(y_test.T[0], y_pred.T[0]))
    # print(accuracy_score(y_test.T[0], y_pred.T[0]) * accuracy_score(y_test.T[1], y_pred.T[1])) #ALL must TRUE metrics
# Out:
# 0.625
# 0.5625
# 0.8125
# 0.8125
# 0.875
# 0.75
# 0.75
# 0.75
# 0.75
# 0.75
# 0.8125
# 0.75
# 0.8125
# 0.8125
# 0.75
# 0.75
# 0.75
# 0.75
# 0.75
# 0.75

# %%
#use best neighbor to train (only for class classifier)
knn = KNN.KNN(num_neighbor = 5)
    # print(x_train)
knn.train(x_train_rd, y_train.T[0])
y1_pred = knn.infer(pca.transform(x_test))
    # print(y_pred.T[0])
    # print(loss.hamming_score(y_test, y_pred))
print(accuracy_score(y_test.T[0], y1_pred))
# Out:
# 0.875

# %%
#linearRegression part (for energy regressor)
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(x_train_rd, y_train.T[1])
y2_pred = lr.predict(pca.transform(x_test))
print(y2_pred)
print(y_test.T[0])
print(np.square(y_test.T[1] - y2_pred).mean(axis=0))
# Out:
# [5.99388129 5.91173742 5.18818131 4.29104553 6.33861241 6.25812211
#  5.83804257 4.40266981 2.73528786 6.11259422 6.21935221 5.64970895
#  5.76365994 5.14627141 5.34230216 6.20024043]
# [3 3 3 2 3 3 3 1 2 3 3 3 3 1 3 1]
# 1.1378896780638388

# %%
mr = MusicRecognition.MusicRecognition(knn, lr, pca)
saver.saveObj("cache/mr.bin",mr)
